# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f=pd.read_csv('fish_cleaned.csv')

# %%
f.head()
# Out:
#      ph  cond          ca         so4        no3        cl         alk     do  \
# 0  7.92  90.3  520.603664  2023.14771  495.79066  11.32551  207.945967  12.93
# 1  7.92  90.3  520.603664  2023.14771  495.79066  11.32551  207.945967  12.93
# 2  7.92  90.3  520.603664  2023.14771  495.79066  11.32551  207.945967  12.93
# 3  7.92  90.3  520.603664  2023.14771  495.79066  11.32551  207.945967  12.93
# 4  7.92  90.3  520.603664  2023.14771  495.79066  11.32551  207.945967  12.93
#
#    temp  abund  count
# 0  12.2   26.0  552.0
# 1  12.2   24.0  552.0
# 2  12.2   70.0  552.0
# 3  12.2    5.0  552.0
# 4  12.2    1.0  552.0

# %% [markdown]
# Summary Stats Table

# %%
f.describe().T
# Out:
#         count         mean          std        min         25%          50%  \
# ph     4593.0     7.807584     0.459613   6.190000    7.510000     7.850000
# cond   4593.0   357.065307   431.581048  18.000000  131.800000   247.900000
# ca     4593.0  2148.120700  1973.952506  43.347549  995.853254  1500.184776
# so4    4593.0  2300.375387  4597.148100  73.692256  252.195575   485.479168
# no3    4593.0   959.250190  1980.060177   9.435900  112.883256   277.075589
# cl     4593.0   363.341479   666.784574   0.725622   87.099637   180.064581
# alk    4593.0  1730.006108  1159.986319   6.278784  854.576715  1522.180082
# do     4593.0     8.216368     1.757313   3.390000    7.220000     8.300000
# temp   4593.0    20.895799     4.292712   5.530000   18.500000    21.570000
# abund  4593.0    43.811670   105.378902   1.000000    3.000000    10.000000
# count  4593.0   833.610059   812.968634   1.000000  241.000000   542.000000
#
#                75%           max
# ph        8.120000      9.290000
# cond    386.250000   4000.000000
# ca     2541.961404  13163.372680
# so4    1760.728193  32003.597560
# no3     854.468882  18022.569000
# cl      337.710341   7220.786840
# alk    2273.172864   6175.374547
# do        9.200000     16.380000
# temp     24.180000     30.100000
# abund    37.000000   1835.000000
# count  1147.000000   4739.000000

# %% [markdown]
# All variables are numerical. No categorical variables in this dataset \
# \
# Histograms for each variable in fish

# %%
try:
    fig,ax=plt.subplots(3,4,figsize=(15,10))
    fig.delaxes(ax[2,3]) # delete graph 12, 0 based index here
    for i in range(ax.shape[0]):
        for j in range(ax.shape[1]):
            sns.histplot(f[f.columns[i*4+j]], ax=ax[i][j])
            fig.axes[3].set_yscale('log') # SO4
            fig.axes[4].set_yscale('log') # NO3
            fig.axes[5].set_yscale('log') # Cl
            fig.axes[9].set_yscale('log') # abund
except IndexError:
    pass

# %% [markdown]
# Reviewing for Outliers and Anomalies \
# \
# Boxplots for each variable in fish

# %%
#fig,ax=plt.subplots()
sns.boxplot(f)
plt.ylim(0,5000)
#ax.set_yscale("log")
# Out:
# /usr/local/lib/python3.10/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# (0.0, 5000.0)

# %%
fig,ax=plt.subplots(figsize=(14,12))
sns.heatmap(f.corr(),linewidths=.1, annot=True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  [Text(0, 0.5, 'ph'),
#   Text(0, 1.5, 'cond'),
#   Text(0, 2.5, 'ca'),
#   Text(0, 3.5, 'so4'),
#   Text(0, 4.5, 'no3'),
#   Text(0, 5.5, 'cl'),
#   Text(0, 6.5, 'alk'),
#   Text(0, 7.5, 'do'),
#   Text(0, 8.5, 'temp'),
#   Text(0, 9.5, 'abund'),
#   Text(0, 10.5, 'count')])

# %%
sns.pairplot(f)
